# %%
# %pylab inline

# %%
import dataikuapi

key_id = "admin"
key_secret = "rj525oD*K2pH"

client = dataikuapi.FMClientAWS("http://ec2-52-14-71-10.us-east-2.compute.amazonaws.com", key_id, key_secret)

# %%
client.list_instances()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /home/data/dss_107/code-envs/python/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# /home/data/dss_107/code-envs/python/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# /home/data/dss_107/code-envs/python/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...
